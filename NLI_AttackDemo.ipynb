# %% [markdown]
# ## Setup

# %%
import keras
import numpy as np
import pickle
from time import time

# %%
from snli_rnn import build_model
from attacks import EntailmentAttack
# Out:
# 82
# 62
# 59
# 55
# 57
# 30
# RNN / Embed / Sent = None, 300, 300
# GloVe / Trainable Word Embeddings = True, False

# %%
# %load_ext autoreload
# %autoreload 2

# %%
with open('./nli_tokenizer.pkl', 'rb') as fh:
    tokenizer = pickle.load(fh)

# %%
with open('./nli_testing.pkl', 'rb') as fh:
    test = pickle.load(fh)

vocab= {w:i for (w, i) in tokenizer.word_index.items()}
inv_vocab = {i:w for (w,i) in vocab.items()}

# %%
def reconstruct(sent, inv_vocab):
    word_list = [inv_vocab[w] for w in sent if w != 0]
    return ' '.join(word_list)

# %% [markdown]
# ## Building the model

# %%
VOCAB = len(tokenizer.word_counts) + 1
LABELS = {'contradiction': 0, 'neutral': 1, 'entailment': 2}

# %%
model = build_model()
# Out:
# Loading GloVe
# Total number of null word embeddings:
# 4043

# %%
model.load_weights('./nli_model.h5')

# %% [markdown]
# ## Test accuracy

# %%
test_accuracy = model.evaluate([test[0], test[1]], test[2])[1]
print('\nTest accuracy = ', test_accuracy)
# Out:
# 307/307 [==============================] - 1s 4ms/step - loss: 0.4965 - accuracy: 0.8221
#
# Test accuracy =  0.8220683932304382

# %% [markdown]
# ## Fooling the model

# %%
dist_mat = np.load('./aux_files/nli_dist_counter_42390.npy')
skip_words = np.load('./aux_files/nli_missed_embeddings_counter_42390.npy')

# %%
def visulaize_result(model, attack_input, attack_output):
    str_labels = ['Contradiction', 'neutral', 'entailment']
    orig_pred = model.predict(attack_input)
    adv_pred = model.predict([attack_output[0][np.newaxis,:], attack_output[1][np.newaxis,:]])
    print('Original pred = {} ({:.2f})'.format(str_labels[np.argmax(orig_pred[0])], np.max(orig_pred[0])))
    print(reconstruct(attack_input[0].ravel(), inv_vocab) , ' || ', reconstruct(attack_input[1].ravel(), inv_vocab))
    print('-' * 40)
    print('New pred = {} ({:.2f})'.format(str_labels[np.argmax(adv_pred[0])], np.max(adv_pred[0])))
    print(reconstruct(attack_output[0].ravel(), inv_vocab) , ' || ', reconstruct(attack_output[1].ravel(), inv_vocab))

# %%
adversary = EntailmentAttack(model, dist_mat, pop_size=128, max_iters=12, n1=5)

# %%
TEST_SIZE = 500
test_idxs = np.random.choice(len(test[0]), size=TEST_SIZE, replace=False)
test_list = []
input_list = []
output_list = []
dist_list = []

# %%
test_times = []

# %%
success_count = 0
for i in range(TEST_SIZE):
    print('\n')
    test_idx = test_idxs[i]
    attack_input = [test[0][test_idx][np.newaxis,:], test[1][test_idx][np.newaxis,:]]
    if np.sum(np.sign(attack_input[1])) < 10:
        continue
    attack_pred = np.argmax(model.predict(attack_input))
    true_label = np.argmax(test[2][test_idx])
    if attack_pred != true_label:
        print('Wrong classified')
    else:
        if true_label == 2:
            target = 0
        elif true_label == 0:
            target = 2
        else:
            target = 0 if np.random.uniform() < 0.5 else 2
        start_time = time()
        attack_result = adversary.attack(attack_input, target)
        if attack_result is None:
            print('**** Attack failed **** ')
        else:
            success_count += 1
            print('***** DONE ', len(test_list) , '------' )
            visulaize_result(model, attack_input, attack_result)
            test_times.append(time()-start_time)
        test_list.append(test_idx)
        input_list.append(attack_input)
        output_list.append(attack_result)
print(success_count / len(test_list))
# Out:
# 1/1 [==============================] - 1s 746ms/step
# 4/4 [==============================] - 0s 7ms/step
# 0  :  0.3974849
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  0 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# Original pred = entailment (0.93)
# A lady sitting on a bench with a book on her lap with a boy and girl on either side of her .  ||  A woman and two kids next to each other .
# ----------------------------------------
# New pred = Contradiction (0.76)
# A lady sitting on a bench with a book on her lap with a boy and girl on either side of her .  ||  A dame and two kids next pour each other .
#
#
# 1/1 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 5ms/step
# 0  :  0.10855479
# 4/4 [==============================] - 0s 5ms/step
# 1  :  0.10855479
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.10855479
# 4/4 [==============================] - 0s 4ms/step
# 3  :  0.10855479
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.10855479
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.11050483
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.1451204
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.15439785
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.16935508
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.16935508
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.16935508
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.16935508
# **** Attack failed ****
#
#
#
#
# 1/1 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  2 ------
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# Original pred = Contradiction (0.45)
# A woman in an American military uniform sits at a table and writes the words `` sad , '' `` depressed , '' and `` hatred '' on a large sheet of white paper .  ||  A woman in an American green military uniform is smiling .
# ----------------------------------------
# New pred = entailment (0.43)
# A woman in an American military uniform sits at a table and writes the words `` sad , '' `` depressed , '' and `` hatred '' on a large sheet of white paper .  ||  A woman in an American green military uniform exists smiling .
#
#
#
#
#
#
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 5ms/step
# 0  :  0.3531392
# 4/4 [==============================] - 0s 5ms/step
# ***** DONE  3 ------
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.83)
# Two teens trying to win a prize at a carnival .  ||  The two young teens tried to throw the ball into the basket to win the big bear .
# ----------------------------------------
# New pred = Contradiction (0.52)
# Two teens trying to win a prize at a carnival .  ||  The two young teens tried to throw the ball into the basketball to victorious the big bear .
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  4 ------
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = entailment (0.75)
# A man running in a race passes by spectators .  ||  A man is running by people who are watching .
# ----------------------------------------
# New pred = Contradiction (0.57)
# A man running in a race passes by spectators .  ||  A man is execution by people who are watching .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 4ms/step
# 0  :  0.14463004
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.1909941
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.23313674
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.33300108
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.45518053
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.45518053
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.46813086
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.4853843
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  5 ------
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.88)
# A black and white dog jumps for a tennis ball .  ||  A border collie is jumping to catching a toy .
# ----------------------------------------
# New pred = entailment (0.50)
# A black and white dog jumps for a tennis ball .  ||  A boundary terrier exists leaps the capture a toy .
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.10077892
# 4/4 [==============================] - 0s 5ms/step
# 1  :  0.18955293
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.28151786
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.28151786
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.28151786
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  6 ------
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# Original pred = Contradiction (0.96)
# Two young girls show prints of a line drawing of an animal .  ||  Two young boys show prints of a line drawing of inanimate objects .
# ----------------------------------------
# New pred = entailment (0.58)
# Two young girls show prints of a line drawing of an animal .  ||  Two youthful guy displaying footprint of a line drawing of inanimate objects .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 20ms/step
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.19111651
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  7 ------
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# Original pred = neutral (0.90)
# Two dogs run together near the leaves .  ||  The two dogs are running to play in the leaves .
# ----------------------------------------
# New pred = Contradiction (0.53)
# Two dogs run together near the leaves .  ||  The two dogs are running to gaming in the spreadsheets .
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 4ms/step
# 0  :  0.19350217
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.27409154
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.31197712
# 4/4 [==============================] - 0s 4ms/step
# 3  :  0.38432005
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  8 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 39ms/step
# Original pred = entailment (0.85)
# A man is looking at the camera posing for a photo with his arm around a woman who is looking away .  ||  A man is looking at the camera for a photo with his arm around a lady who is looking away .
# ----------------------------------------
# New pred = Contradiction (0.54)
# A man is looking at the camera posing for a photo with his arm around a woman who is looking away .  ||  A man is search into the camera onto a photo with his arm around a woman who is quest away .
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  9 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = entailment (0.74)
# A skier is heading into a grove of trees .  ||  There is snow on the ground in this picture .
# ----------------------------------------
# New pred = Contradiction (0.53)
# A skier is heading into a grove of trees .  ||  There is snowstorm on the ground in this picture .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# Wrong classified
#
#
#
#
# 1/1 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.014438557
# 4/4 [==============================] - 0s 4ms/step
# 1  :  0.027262863
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.04163987
# 4/4 [==============================] - 0s 4ms/step
# 3  :  0.04511543
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.04511543
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.04511543
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.047581617
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.08597074
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.08597074
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.08597074
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.0965426
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.0970543
# **** Attack failed ****
#
#
# 1/1 [==============================] - 0s 9ms/step
# Wrong classified
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.21691637
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  11 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = Contradiction (0.93)
# Six males , four with shirts and two without , have taken a break from their construction work on a building .  ||  A soccer team is standing outside of a building .
# ----------------------------------------
# New pred = entailment (0.46)
# Six males , four with shirts and two without , have taken a break from their construction work on a building .  ||  A soccer team exists permanent outside of a building .
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# Wrong classified
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.1490199
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  12 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = Contradiction (0.65)
# A boy pushing a girl on a toy SUV .  ||  A boy and girl are waiting patiently in line .
# ----------------------------------------
# New pred = entailment (0.61)
# A boy pushing a girl on a toy SUV .  ||  A boy and girl be awaits elaborately in line .
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.042694442
# 4/4 [==============================] - 0s 4ms/step
# 1  :  0.045845333
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.09837959
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.09837959
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.09837959
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.09837959
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.09837959
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.09837959
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.09837959
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.09837959
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.09837959
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.09837959
# **** Attack failed ****
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 5ms/step
# 0  :  0.036176432
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.04210029
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.07610165
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.07610165
# 4/4 [==============================] - 0s 4ms/step
# 4  :  0.14114496
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.14114496
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.33566898
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.33566898
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.33733085
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.36249498
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.36249498
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.4383775
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  15 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.54)
# A yellow car drives across a snowy path .  ||  A taxi cab is driving down a path of snow .
# ----------------------------------------
# New pred = Contradiction (0.79)
# A yellow car drives across a snowy path .  ||  A taxi cab is driving down a road of snow .
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.009065457
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.05468086
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.083287
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.13521944
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.17729083
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.17729083
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.17729083
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.17729083
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.18281373
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.18281373
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.18281373
# 4/4 [==============================] - 0s 5ms/step
# 11  :  0.18281373
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 4ms/step
# 0  :  0.019538103
# 4/4 [==============================] - 0s 4ms/step
# 1  :  0.026140677
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.026140677
# 4/4 [==============================] - 0s 4ms/step
# 3  :  0.028764078
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.033532217
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.03429328
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.03429328
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.03429328
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.03429328
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.03429328
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.03690316
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.041789427
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 11ms/step
# Wrong classified
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 4ms/step
# 0  :  0.22219369
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.30979982
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.3651712
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.3651712
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.3651712
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.37908417
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.43505868
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.43505868
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.4554824
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.4696616
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.4753093
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  18 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# Original pred = neutral (0.90)
# A lady in a dark coat is sitting with many people around her .  ||  A woman is attempting an eating competition at a festival .
# ----------------------------------------
# New pred = Contradiction (0.50)
# A lady in a dark coat is sitting with many people around her .  ||  A women is attempts an diet compete in a celebratory .
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  19 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# Original pred = entailment (0.93)
# A woman and little girl look into a display case .  ||  A women and little girl are looking at something .
# ----------------------------------------
# New pred = Contradiction (0.96)
# A woman and little girl look into a display case .  ||  A women and little girl are looking at nothing .
#
#
#
#
#
#
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.2726092
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  20 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = entailment (0.95)
# A group of men playing rugby on the sand .  ||  a group of men playing sports in the sand .
# ----------------------------------------
# New pred = Contradiction (0.66)
# A group of men playing rugby on the sand .  ||  a panel of males toying sports in the sand .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.20405607
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  21 ------
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = entailment (0.92)
# A man standing in front of a building on the phone as two men to the side pain on the side .  ||  a guy near a building stands by two other men
# ----------------------------------------
# New pred = Contradiction (0.52)
# A man standing in front of a building on the phone as two men to the side pain on the side .  ||  a boy closest a building stands by two other mens
#
#
# 1/1 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.32700688
# 4/4 [==============================] - 0s 4ms/step
# 1  :  0.3749048
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  22 ------
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.83)
# Two girls playing catch on a lawn  ||  Sisters are tossing a frisbee back and forth in the park .
# ----------------------------------------
# New pred = Contradiction (0.57)
# Two girls playing catch on a lawn  ||  Sisters are throwing a frisbee backwards and forth throughout the park .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.010990679
# 4/4 [==============================] - 0s 4ms/step
# 1  :  0.035089515
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.035089515
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.035089515
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.038051724
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.038051724
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.038051724
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.038051724
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.053947687
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.06755626
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.06755626
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.06755626
# **** Attack failed ****
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  24 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.85)
# A guy in a blue shirt chases a guy in an orange shirt during a game of flag football .  ||  Two people are playing flag football at the park .
# ----------------------------------------
# New pred = Contradiction (0.64)
# A guy in a blue shirt chases a guy in an orange shirt during a game of flag football .  ||  Two people are playing flag soccer at the park .
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.02298992
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.060760304
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.060760304
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.061187007
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.11782841
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.12448625
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.13310799
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.15542403
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.15542403
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.15579906
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.24891962
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.24891962
# **** Attack failed ****
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# Wrong classified
#
#
#
#
#
#
# 1/1 [==============================] - 0s 16ms/step
# Wrong classified
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.1647112
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  26 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = entailment (0.81)
# A woman and child are on a boat and the woman is looking out into the ocean through a scope .  ||  A lady and a child are on a boat and the lady is looking out into the ocean through a scope .
# ----------------------------------------
# New pred = Contradiction (0.45)
# A woman and child are on a boat and the woman is looking out into the ocean through a scope .  ||  A lady and a infantile are on a ship and the lady is looking out into the ocean through a scope .
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.03808683
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.074203804
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.07739104
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.08506277
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.10128951
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.115257576
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.1321569
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.14678983
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.14678983
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.14678983
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.14678983
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.16776042
# **** Attack failed ****
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.45408845
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  28 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.54)
# A woman in a gray shirt is looking at something .  ||  A woman in a gray shirt looking at her book .
# ----------------------------------------
# New pred = Contradiction (0.55)
# A woman in a gray shirt is looking at something .  ||  A woman in a gray sweater looking into her book .
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.010547446
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.02010069
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.04217847
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.04217847
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.054165937
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.06788009
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.06788009
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.06788009
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.076323025
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.1293961
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.1293961
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.1293961
# **** Attack failed ****
#
#
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.05863223
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.11514135
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.13916874
# 4/4 [==============================] - 0s 4ms/step
# 3  :  0.27698833
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.27698833
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.42455867
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.42455867
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.42455867
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.45094508
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.47262296
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.47262296
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.47262296
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.10548648
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.19162318
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.19162318
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.20017757
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.25842372
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.26095462
# 4/4 [==============================] - 0s 16ms/step
# 6  :  0.41678086
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.41678086
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.41678086
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.41678086
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.41678086
# 4/4 [==============================] - 0s 5ms/step
# 11  :  0.41678086
# **** Attack failed ****
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 5ms/step
# 0  :  0.0015060378
# 4/4 [==============================] - 0s 4ms/step
# 1  :  0.004890815
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.007936777
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.007936777
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.007936777
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.011289829
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.015076937
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.015076937
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.015730409
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.015730409
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.015730409
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.015730409
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  33 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.58)
# A woman drives a bike wearing a white blouse with her brown hair blowing in the wind .  ||  The woman is riding her bike to conserve fuel use .
# ----------------------------------------
# New pred = entailment (0.75)
# A woman drives a bike wearing a white blouse with her brown hair blowing in the wind .  ||  The woman is riding her bike to maintaining fuel use .
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.0237344
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.0384352
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.041621815
# 4/4 [==============================] - 0s 4ms/step
# 3  :  0.08947114
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.08947114
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.10023964
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.10978485
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  34 ------
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = Contradiction (0.82)
# A man is sitting on a blue bench with a blue blanket covering his face .  ||  A man is playing chess while wearing a green tutu .
# ----------------------------------------
# New pred = entailment (0.41)
# A man is sitting on a blue bench with a blue blanket covering his face .  ||  A males exists playback chessboard despite wears a greenery tutu .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 4ms/step
# 0  :  0.001024396
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.0067463433
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.012335964
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.012335964
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.02422414
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.02422414
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.037376117
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.060233157
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.060233157
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.060233157
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.060233157
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.06977607
# **** Attack failed ****
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.034587245
# 4/4 [==============================] - 0s 4ms/step
# 1  :  0.10769763
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.10769763
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.116210096
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.121892706
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.121892706
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.13305171
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.13305171
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.24164164
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.24164164
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.2902315
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.2902315
# **** Attack failed ****
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.083248205
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.13754295
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.13754295
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.13754295
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.16076508
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.16076508
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.16076508
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.16076508
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.16076508
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.16076508
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.16076508
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.16076508
# **** Attack failed ****
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  38 ------
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.39)
# Scientists frantically research ways to finally male baldness .  ||  A group of scientists are examining a bald man while shaking their heads
# ----------------------------------------
# New pred = entailment (0.48)
# Scientists frantically research ways to finally male baldness .  ||  A group of scientists are examining a bald man while shivering their heads
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# Wrong classified
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.1506845
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.19583583
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.3228062
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.3228062
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.3228062
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.3228062
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.3228062
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.3228062
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.3228062
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.3228062
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.3228062
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.3503711
# **** Attack failed ****
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  40 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# Original pred = neutral (0.64)
# A woman and little girl look into a display case .  ||  A women is buying a little girl a present .
# ----------------------------------------
# New pred = entailment (0.90)
# A woman and little girl look into a display case .  ||  A women is purchases a little girl a present .
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  41 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = Contradiction (0.38)
# A female gymnast in black and red being coached on bar skills .  ||  The female gymnast is on her way to the gym .
# ----------------------------------------
# New pred = entailment (0.63)
# A female gymnast in black and red being coached on bar skills .  ||  The female gymnast is on her manner to the gym .
#
#
# 1/1 [==============================] - 0s 10ms/step
# Wrong classified
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.22537684
# 4/4 [==============================] - 0s 4ms/step
# 1  :  0.22537684
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.25585482
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.25714135
# 4/4 [==============================] - 0s 4ms/step
# 4  :  0.25714135
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.25961035
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.25961035
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.25961035
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.27123603
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.2821605
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.2821605
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.2821605
# **** Attack failed ****
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.13207619
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.16476534
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.16476534
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.17809822
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.19855672
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.19855672
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.19855672
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.19855672
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.2543112
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.2543112
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.2543112
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.2543112
# **** Attack failed ****
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.10472919
# 4/4 [==============================] - 0s 4ms/step
# 1  :  0.23826274
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.36013445
# 4/4 [==============================] - 0s 4ms/step
# 3  :  0.3841988
# 4/4 [==============================] - 0s 4ms/step
# 4  :  0.3841988
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.3841988
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.3841988
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.3841988
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.3841988
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.3841988
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.3841988
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.3841988
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.007335544
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.04265911
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.06989407
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.06989407
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.13233665
# 4/4 [==============================] - 0s 18ms/step
# ***** DONE  45 ------
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = Contradiction (1.00)
# A group walking in the middle of a walkway with a green divider , and a woman is walking by herself off to the right .  ||  The group is eating lunch at a small cafe .
# ----------------------------------------
# New pred = entailment (0.74)
# A group walking in the middle of a walkway with a green divider , and a woman is walking by herself off to the right .  ||  The group is nourishment dine in a minor cafes .
#
#
#
#
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.22432615
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  46 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = entailment (0.72)
# A man looks back while laughing and walking .  ||  A man is looks behind his shoulder to laugh .
# ----------------------------------------
# New pred = Contradiction (0.37)
# A man looks back while laughing and walking .  ||  A man is looks backside his shoulder the laughter .
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.06150863
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.14049065
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.14049065
# 4/4 [==============================] - 0s 4ms/step
# 3  :  0.14049065
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.14049065
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.3062702
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.3062702
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.3062702
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.3062702
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.3062702
# 4/4 [==============================] - 0s 7ms/step
# 10  :  0.3062702
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.3062702
# **** Attack failed ****
#
#
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.21379697
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.27832258
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.32654652
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.32654652
# 4/4 [==============================] - 0s 4ms/step
# 4  :  0.33427703
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.33427703
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.33427703
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.3557763
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.3557763
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.3557763
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.3557763
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.3557763
# **** Attack failed ****
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# Wrong classified
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.17419375
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  49 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = entailment (0.93)
# Group of people standing on a snow covered ground , some are holding brooms , there is a dog with the group .  ||  Group of people with a dog nearby are outside .
# ----------------------------------------
# New pred = Contradiction (0.79)
# Group of people standing on a snow covered ground , some are holding brooms , there is a dog with the group .  ||  Group of people with a doggy nearby are outer .
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.35739017
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  50 ------
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.48)
# An old man with a package poses in front of an advertisement .  ||  A man poses in front of an ad for beer .
# ----------------------------------------
# New pred = Contradiction (0.54)
# An old man with a package poses in front of an advertisement .  ||  A man puts in front of an ad in beer .
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.15669109
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.15669109
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.15669109
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.2006274
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.2579005
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.2579005
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.2579005
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.2579005
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.2579005
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.2579005
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.25805783
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.25805783
# **** Attack failed ****
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.13366434
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.20192355
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.3092637
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.3092637
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.3092637
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  52 ------
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = entailment (0.50)
# A man with a pinstriped shirt and tan slacks adjust his tie while looking at a apple laptop computer .  ||  A man adjusts his new tie in front of a laptop
# ----------------------------------------
# New pred = Contradiction (0.50)
# A man with a pinstriped shirt and tan slacks adjust his tie while looking at a apple laptop computer .  ||  A man adjusting his newer tying onto front du a portable
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.15836696
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.4176175
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.43565676
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  53 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.88)
# A man looks intent while sculpting a .  ||  The man is trying to add color to his sculpture .
# ----------------------------------------
# New pred = entailment (0.52)
# A man looks intent while sculpting a .  ||  The man is trying to added colored of his sculpture .
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.03992337
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.07382764
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.09803952
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.20270216
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.20395447
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.20395447
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.20395447
# 4/4 [==============================] - 0s 6ms/step
# 7  :  0.20395447
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.20395447
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.20395447
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.20395447
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.20395447
# **** Attack failed ****
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# Wrong classified
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.0705662
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.12951875
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.16484763
# 4/4 [==============================] - 0s 4ms/step
# 3  :  0.25798452
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.25798452
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.25798452
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.25798452
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.25798452
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.25798452
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.25798452
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.25798452
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.25798452
# **** Attack failed ****
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.0013041502
# 4/4 [==============================] - 0s 4ms/step
# 1  :  0.00251713
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.0072700754
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.0072700754
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.0072700754
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.009653425
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.0106852
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.01576482
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.01576482
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.017478209
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.02267037
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.02267037
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  57 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 41ms/step
# Original pred = Contradiction (0.98)
# A young woman wearing a yellow shirt and off-white shorts is reading a book while sitting on a park bench .  ||  A man reading a book while sitting on a bench .
# ----------------------------------------
# New pred = entailment (0.55)
# A young woman wearing a yellow shirt and off-white shorts is reading a book while sitting on a park bench .  ||  A fella reading a book while sitting on a bench .
#
#
#
#
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.15984254
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.41737702
# 4/4 [==============================] - 0s 3ms/step
# ...
# 3  :  0.46215138
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.46215138
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  89 ------
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 11ms/step
# Original pred = entailment (0.89)
# Two young girls in bathing suits laugh while standing under a fountain of water .  ||  Two young girls are standing under a fountain of water .
# ----------------------------------------
# New pred = Contradiction (0.49)
# Two young girls in bathing suits laugh while standing under a fountain of water .  ||  Two youthful woman be standing underneath a trout of water .
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.08117906
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.13500229
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.15519391
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.25679862
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.25679862
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.25679862
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.25679862
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.2633549
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.2633549
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.2633549
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.2633549
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.2633549
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.2817586
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  91 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.88)
# The girl wearing a brown jacket whilst walking in snow .  ||  The lady wearing a jacket is looking for her lost dog .
# ----------------------------------------
# New pred = Contradiction (0.61)
# The girl wearing a brown jacket whilst walking in snow .  ||  The lady port a jacket is looking at his lost dog .
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  92 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.78)
# A group of mountain climbers rests at the summit .  ||  A group of climbers celebrates at the top of Everest .
# ----------------------------------------
# New pred = Contradiction (0.60)
# A group of mountain climbers rests at the summit .  ||  A group of climbers celebrates at the upstairs of Everest .
#
#
# 1/1 [==============================] - 0s 10ms/step
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# Wrong classified
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  93 ------
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = Contradiction (0.76)
# two big feathers on the front is sitting by himself on a bench in front of a building with a blue and white patterned piece of wheeled luggage to his right while he rests both his hands on a walking stick .  ||  A man in a red cape and a hat with three feathers sits by himself .
# ----------------------------------------
# New pred = entailment (0.67)
# two big feathers on the front is sitting by himself on a bench in front of a building with a blue and white patterned piece of wheeled luggage to his right while he rests both his hands on a walking stick .  ||  A man in a rouge cape and a hat with three feathers sits by himself .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.00010598143
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.00017174109
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.00023133785
# 4/4 [==============================] - 0s 4ms/step
# 3  :  0.00023133785
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.00023133785
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.00023133785
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.00026964713
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.00026964713
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.00026964713
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.00026964713
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.00026964713
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.00026964713
# **** Attack failed ****
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.036620267
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.0548586
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.06114533
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.06114533
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.06114533
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.064664006
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.064664006
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.064664006
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.064664006
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.07879009
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.07879009
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.07879009
# **** Attack failed ****
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.25011423
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.37165764
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  96 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# Original pred = Contradiction (0.58)
# A man in a colorful shirt and a lady in a white blouse sign copies of books for people .  ||  A man in a colorful shirt and a lady in a white blouse give candy to people .
# ----------------------------------------
# New pred = entailment (0.60)
# A man in a colorful shirt and a lady in a white blouse sign copies of books for people .  ||  A man in a colorful shirt and a lady in a white blouse give confectionery to humans .
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.18542904
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.2529766
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.3554424
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  97 ------
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = entailment (0.70)
# A man smokes while leaning against a pillar , which has a `` missing person '' flier posted on it .  ||  a guy smoking against a wall with a flier on it
# ----------------------------------------
# New pred = Contradiction (0.49)
# A man smokes while leaning against a pillar , which has a `` missing person '' flier posted on it .  ||  a boy smokes against a wall with a aviator onto it
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.11329372
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.19044223
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.263754
# 4/4 [==============================] - 0s 4ms/step
# ***** DONE  98 ------
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = Contradiction (0.98)
# A boy in a green shirt on a skateboard on a stone wall with graffiti  ||  A boy in a green shirt rollerblading through the tunnel .
# ----------------------------------------
# New pred = entailment (0.49)
# A boy in a green shirt on a skateboard on a stone wall with graffiti  ||  A dude in a greenery shirt rollerblading through the tunneling .
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.0010003239
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.0025026635
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.0072348383
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.00998633
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.022707893
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.022707893
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.022707893
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.02672504
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.02672504
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.02672504
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.028976725
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.031826045
# **** Attack failed ****
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.12619583
# 4/4 [==============================] - 0s 4ms/step
# 1  :  0.18548849
# 4/4 [==============================] - 0s 4ms/step
# 2  :  0.24472092
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.24472092
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.24472092
# 4/4 [==============================] - 0s 3ms/step
# 5  :  0.27478483
# 4/4 [==============================] - 0s 3ms/step
# 6  :  0.27478483
# 4/4 [==============================] - 0s 4ms/step
# 7  :  0.27478483
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.28691643
# 4/4 [==============================] - 0s 4ms/step
# 9  :  0.28691643
# 4/4 [==============================] - 0s 4ms/step
# 10  :  0.28691643
# 4/4 [==============================] - 0s 4ms/step
# 11  :  0.30079785
# **** Attack failed ****
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.3157989
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.387022
# 4/4 [==============================] - 0s 5ms/step
# 2  :  0.46186006
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.46186006
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  101 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.76)
# Four people walk across stepping stones in a body of water .  ||  The people are trying to cross a river without getting wet .
# ----------------------------------------
# New pred = Contradiction (0.56)
# Four people walk across stepping stones in a body of water .  ||  The pueblo be striving to cross a creek no get humid .
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  102 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.45)
# A young boy , wearing a jesters hat is enjoying himself sledding .  ||  A young boy wearing a hat is cold while he sleds .
# ----------------------------------------
# New pred = entailment (0.76)
# A young boy , wearing a jesters hat is enjoying himself sledding .  ||  A young boy wearing a hat is colder while he sleds .
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  103 ------
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# Original pred = neutral (0.82)
# The little boy is smiling as he crosses a rope on an assault course .  ||  Some people have gone to the woods for training .
# ----------------------------------------
# New pred = Contradiction (0.61)
# The little boy is smiling as he crosses a rope on an assault course .  ||  Some people have gone to the antlers for training .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.09722726
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.17834184
# 4/4 [==============================] - 0s 3ms/step
# 2  :  0.23551777
# 4/4 [==============================] - 0s 7ms/step
# 3  :  0.31244457
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.3330052
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.42170528
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.42170528
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.44054085
# 4/4 [==============================] - 0s 4ms/step
# 8  :  0.44054085
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  104 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.93)
# Three men on mountain bikes go over a sand hill .  ||  Men on bikes go over a sand hill to get to the finish line .
# ----------------------------------------
# New pred = Contradiction (0.50)
# Three men on mountain bikes go over a sand hill .  ||  Men on motorbikes go completed a sand hale of receives of the finished line .
#
#
#
#
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.00893212
# 4/4 [==============================] - 0s 3ms/step
# 1  :  0.015563629
# 4/4 [==============================] - 0s 7ms/step
# 2  :  0.02143313
# 4/4 [==============================] - 0s 3ms/step
# 3  :  0.02143313
# 4/4 [==============================] - 0s 3ms/step
# 4  :  0.028081987
# 4/4 [==============================] - 0s 4ms/step
# 5  :  0.03538776
# 4/4 [==============================] - 0s 4ms/step
# 6  :  0.03538776
# 4/4 [==============================] - 0s 3ms/step
# 7  :  0.03538776
# 4/4 [==============================] - 0s 3ms/step
# 8  :  0.03538776
# 4/4 [==============================] - 0s 3ms/step
# 9  :  0.03538776
# 4/4 [==============================] - 0s 3ms/step
# 10  :  0.03538776
# 4/4 [==============================] - 0s 3ms/step
# 11  :  0.035693772
# **** Attack failed ****
#
#
# 1/1 [==============================] - 0s 9ms/step
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# Wrong classified
#
#
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  106 ------
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = neutral (0.67)
# A young child climbing a stack of logs even though the sign warns against it .  ||  A kid who 's too young to read climbs a dangerous stack of logs .
# ----------------------------------------
# New pred = entailment (0.49)
# A young child climbing a stack of logs even though the sign warns against it .  ||  A kid who 's too young to read climbs a risks stack of logs .
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# Wrong classified
#
#
#
#
# 1/1 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 3ms/step
# 0  :  0.033672165
# 4/4 [==============================] - 0s 3ms/step
# ***** DONE  107 ------
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Original pred = entailment (0.97)
# A woman in a black jacket and a black and white striped skirt is watching a woman talking to a little boy sitting on concrete steps .  ||  A person is talking to a child while another person watches .
# ----------------------------------------
# New pred = Contradiction (0.62)
# A woman in a black jacket and a black and white striped skirt is watching a woman talking to a little boy sitting on concrete steps .  ||  A anyone is talking to a child despite another anybody watches .
#
#
#
#
# 0.5925925925925926

# %%
print('Success rate: ', (success_count / len(test_list)))
# Out:
# Success rate:  0.5925925925925926
