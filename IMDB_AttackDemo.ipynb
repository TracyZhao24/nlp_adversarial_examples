# %% [markdown]
# ### Setup

# %%
import numpy as np
import tensorflow as tf

from keras.preprocessing.sequence import pad_sequences
import pickle

# %%
import data_utils
import glove_utils
import models
import display_utils
from goog_lm import LM

# %%
import lm_data_utils
import lm_utils

# %%
np.random.seed(1001)
tf.random.set_seed(1001)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
VOCAB_SIZE  = 50000
with open('aux_files/dataset_%d.pkl' %VOCAB_SIZE, 'rb') as f:
    dataset = pickle.load(f)

# %%
doc_len = [len(dataset.test_seqs2[i]) for i in 
           range(len(dataset.test_seqs2))]

# %%
dist_mat = np.load('aux_files/dist_counter_%d.npy' %VOCAB_SIZE)
# Prevent returning 0 as most similar word because it is not part of the dictionary
dist_mat[0,:] = 100000
dist_mat[:,0] = 100000

skip_list = np.load('aux_files/missed_embeddings_counter_%d.npy' %VOCAB_SIZE)

# %% [markdown]
# ### Demonstrating how we find the most similar words

# %%
for i in range(300, 305):
    src_word = i
    nearest, nearest_dist = glove_utils.pick_most_similar_words(src_word, dist_mat,20, 0.5)
        
    print('Closest to `%s` are:' %(dataset.inv_dict[src_word]))
    for w_id, w_dist in zip(nearest, nearest_dist):
          print(' -- ', dataset.inv_dict[w_id], ' ', w_dist)

    print('----')
# Out:
# Closest to `later` are:
#  --  subsequent   0.1832310977139997
#  --  subsequently   0.18671959913400027
#  --  afterward   0.2509214012219996
#  --  afterwards   0.25769589614799937
#  --  thereafter   0.27419810965900004
#  --  trailing   0.3368002712810001
#  --  after   0.3452026123779992
#  --  then   0.3647283933829988
#  --  posterior   0.43108558883900017
#  --  following   0.48330736760399984
# ----
# Closest to `takes` are:
#  --  pick   0.31130546563200046
#  --  taking   0.42471158462800007
#  --  picked   0.4852741249590009
# ----
# Closest to `instead` are:
#  --  conversely   0.3034038049849994
#  --  however   0.3475382865829999
#  --  alternatively   0.39540487543000014
#  --  alternately   0.44396273956000054
#  --  nevertheless   0.47716397579200054
# ----
# Closest to `seem` are:
#  --  seems   0.007052995653000549
#  --  appears   0.3283724473520002
#  --  looks   0.3353463830640009
#  --  transpires   0.45620718549300054
# ----
# Closest to `beautiful` are:
#  --  gorgeous   0.01923644366200028
#  --  wonderful   0.10149643378299933
#  --  splendid   0.10299021060599944
#  --  handsome   0.11803810151499872
#  --  resplendent   0.11808701124700005
#  --  wondrous   0.12150066282500038
#  --  marvelous   0.12519975539099892
#  --  marvellous   0.1283983423189996
#  --  fantastic   0.13626627125499935
#  --  sumptuous   0.14140581277100006
#  --  magnificent   0.14636687160099937
#  --  terrific   0.1560766841779997
#  --  lovely   0.16000762712299954
#  --  ravishing   0.17404625231199988
#  --  sublime   0.1790955769609992
#  --  exquisite   0.18810714172799958
#  --  fabulous   0.20363493095599927
#  --  delightful   0.2046840553089997
#  --  superb   0.21660537682999936
#  --  excellent   0.22435712285300036
# ----

# %% [markdown]
# ### Preparing the dataset

# %%
max_len = 250
train_x = pad_sequences(dataset.train_seqs2, maxlen=max_len, padding='post')
train_y = np.array(dataset.train_y)
test_x = pad_sequences(dataset.test_seqs2, maxlen=max_len, padding='post')
test_y = np.array(dataset.test_y)

# %% [markdown]
# ### Loading the sentiment analysis model

# %%
tf.compat.v1.reset_default_graph()
if tf.compat.v1.get_default_session():
    sess.close()
sess = tf.compat.v1.Session()
batch_size = 1
lstm_size = 128
#max_len =  100

with tf.compat.v1.variable_scope('imdb', reuse=False):
    model = models.SentimentModel(batch_size=batch_size,
                           lstm_size = lstm_size,
                           max_len = max_len,
                           embeddings_dim=300, vocab_size=dist_mat.shape[1],is_train = False)
saver = tf.compat.v1.train.Saver()
saver.restore(sess, './models/imdb_model')
# Out:
# WARNING:tensorflow:From /Users/tracyzhao/Desktop/nlp_adversarial_examples/models.py:34: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /Users/tracyzhao/Desktop/nlp_adversarial_examples/.venv/lib/python3.8/site-packages/keras/src/layers/rnn/legacy_cells.py:793: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /Users/tracyzhao/Desktop/nlp_adversarial_examples/models.py:29: UserWarning: `tf.nn.rnn_cell.BasicLSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   lstm = tf.compat.v1.nn.rnn_cell.BasicLSTMCell(self.lstm_size)
# INFO:tensorflow:Restoring parameters from ./models/imdb_model
# 2024-10-19 18:58:46.502242: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled

# %% [markdown]
# ## The Google Language model

# %%
goog_lm = LM()
# Out:
# LM vocab loading done
# Device mapping: no known devices.
# WARNING:tensorflow:From /Users/tracyzhao/Desktop/nlp_adversarial_examples/lm_utils.py:21: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# Recovering graph.
# INFO:tensorflow:Recovering Graph goog_lm/graph-2016-09-10.pbtxt
# Variable: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# states_init: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_0: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_0/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_0/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_0/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_0/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_0/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_1: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_1/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_1/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_1/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_2: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_2/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_2/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_2/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_2/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_3: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_3/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_3/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_3/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_3/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_4: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_4/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_4/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_4/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_4/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_5: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_5/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_5/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_5/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_5/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_5/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_6: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_6/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_6/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_6/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_6/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_6/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_7: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_7/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_7/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_7/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_7/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/W_7/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# softmax/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/W: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/W/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/W/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/W/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/W/Initializer/random_uniform: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/W/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/W/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/EmbeddingLookupUnique/Unique: (Unique): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/EmbeddingLookupUnique/embedding_lookup: (Gather): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/EmbeddingLookupUnique/Gather: (Gather): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/kernel: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/kernel/Initializer/random_uniform: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/Max: (Max): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_0/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/concat: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/kernel: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/kernel/Initializer/random_uniform: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/Max: (Max): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_1/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/concat_1: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/kernel: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/kernel/Initializer/random_uniform: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/Max: (Max): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_2/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/concat_2: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/kernel: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/kernel/Initializer/random_uniform: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/Max: (Max): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_3/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/concat_3: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/kernel: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/kernel/Initializer/random_uniform: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/Max: (Max): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_4/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/concat_4: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/kernel: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/kernel/Initializer/random_uniform: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/Max: (Max): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_5/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/concat_5: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/kernel: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/kernel/Initializer/random_uniform: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/Max: (Max): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_6/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/concat_6: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/kernel: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/kernel/Initializer/random_uniform: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/kernel/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/Max: (Max): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/cnn_7/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/concat_7: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_0: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_0/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_0/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_0/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_0/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_0/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_1: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_1/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_1/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_1/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_2: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_2/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_2/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_2/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_2/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_3: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_3/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_3/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_3/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_3/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_4: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_4/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_4/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_4/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_4/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_5: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_5/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_5/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_5/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_5/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_5/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_6: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_6/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_6/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_6/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_6/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_6/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_7: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_7/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_7/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_7/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_7/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/W_7/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/concat: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/gate/Sigmoid: (Sigmoid): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_0: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_0/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_0/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_0/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_0/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_0/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_1: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_1/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_1/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_1/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_2: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_2/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_2/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_2/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_2/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_3: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_3/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_3/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_3/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_3/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_4: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_4/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_4/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_4/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_4/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_5: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_5/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_5/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_5/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_5/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_5/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_6: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_6/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_6/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_6/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_6/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_6/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_7: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_7/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_7/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_7/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_7/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/W_7/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/concat: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/tr/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_0/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_0: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_0/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_0/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_0/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_0/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_0/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_1: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_1/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_1/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_1/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_2: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_2/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_2/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_2/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_2/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_3: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_3/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_3/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_3/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_3/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_4: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_4/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_4/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_4/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_4/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_5: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_5/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_5/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_5/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_5/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_5/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_6: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_6/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_6/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_6/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_6/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_6/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_7: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_7/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_7/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_7/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_7/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/W_7/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/concat: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/gate/Sigmoid: (Sigmoid): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_0: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_0/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_0/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_0/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_0/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_0/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_1: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_1/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_1/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_1/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_2: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_2/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_2/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_2/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_2/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_3: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_3/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_3/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_3/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_3/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_4: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_4/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_4/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_4/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_4/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_5: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_5/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_5/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_5/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_5/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_5/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_6: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_6/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_6/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_6/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_6/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_6/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_7: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_7/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_7/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_7/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_7/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/W_7/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/concat: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/b: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/b/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/b/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/tr/Relu: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/dense_1/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_0: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_0/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_0/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_0/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_0/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_0/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_1: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_1/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_1/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_1/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_2: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_2/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_2/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_2/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_2/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_3: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_3/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_3/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_3/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_3/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_4: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_4/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_4/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_4/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_4/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_5: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_5/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_5/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_5/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_5/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_5/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_6: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_6/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_6/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_6/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_6/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_6/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_7: (Variable): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_7/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_7/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_7/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_7/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/W_7/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/concat: (Concat): /job:localhost/replica:0/task:0/device:CPU:0
# char_embedding/proj/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# ...
# 2024-10-19 18:58:53.942285: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_64/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942288: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_65/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942290: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_65/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942293: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_66/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942296: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_66/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942299: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_67/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942302: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_67/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942305: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_68/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942307: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_68/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942310: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_69/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942313: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_69/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942315: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_70/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942318: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_70/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942321: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_71/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942324: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_71/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942326: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_72/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942329: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_72/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942332: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_73/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942334: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_73/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942337: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_74/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942339: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_74/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942342: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_75/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942344: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_75/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942347: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_76/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942349: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_76/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942352: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_77/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942354: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_77/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942357: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_78/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942359: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_78/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942362: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_79/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942364: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_79/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942367: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_80/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942370: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_80/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942372: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_81/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942375: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_81/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942377: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_82/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942380: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_82/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942382: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_83/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942385: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_83/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942387: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_84/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942390: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_84/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942393: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_85/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942395: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_85/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942398: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_86/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942400: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_86/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942403: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_87/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942405: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_87/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942408: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_88/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942411: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_88/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942413: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_89/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942416: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_89/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942418: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_90/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942421: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_90/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942424: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_91/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942426: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_91/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942429: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_92/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942432: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_92/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942434: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_93/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942437: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_93/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942439: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_94/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942442: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_94/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942445: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_95/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942447: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_95/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942450: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_96/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942453: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_96/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942455: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_97/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942459: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_97/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942461: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_98/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942464: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_98/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942466: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_99/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942469: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_99/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942471: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_100/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942474: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_100/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942477: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_101/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942480: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_101/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942482: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_102/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942485: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_102/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942488: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_103/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942490: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_103/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942493: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_104/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942495: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_104/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942498: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_105/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942501: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_105/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942504: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_106/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942506: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_106/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942509: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_107/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942512: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_107/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942515: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_108/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942517: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_108/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942520: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_109/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942522: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_109/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942525: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_110/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942528: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_110/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942530: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_111/tensor_name: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-10-19 18:58:53.942533: I tensorflow/core/common_runtime/placer.cc:114] save/restore_slice_111/shape_and_slice: (Const): /job:localhost/replica:0/task:0/device:CPU:0

# %% [markdown]
# #### Demonstrating the GoogLM

# %%
src_word = dataset.dict['eat']
nearest, nearest_dist = glove_utils.pick_most_similar_words(src_word, dist_mat, 20)
nearest_w = [dataset.inv_dict[x] for x in nearest]
print('Closest to `%s` are %s' %(dataset.inv_dict[src_word], nearest_w))
# Out:
# Closest to `eat` are ['ate', 'eaten', 'comer', 'eating', 'devour', 'consumed', 'swallowed', 'coma', 'devouring', 'devoured', 'ingested', 'tasted', 'dinner', 'meals', 'meal', 'swallow', 'grab', 'supper', 'dine', 'food']

# %%
prefix = 'that'
suffix = 'delicious'
lm_preds = goog_lm.get_words_probs(prefix, nearest_w, suffix)
print('most probable is ', nearest_w[np.argmax(lm_preds)])
# Out:
# most probable is  tasted

# %% [markdown]
# ## Try Attack

# %%
from attacks import GeneticAtack

# %% [markdown]
# ## Main Attack

# %%
# size of each generation
pop_size = 60
# top 8 similar words
n1 = 8

with tf.compat.v1.variable_scope('imdb', reuse=True):
    batch_model = models.SentimentModel(batch_size=pop_size,
                           lstm_size = lstm_size,
                           max_len = max_len,
                           embeddings_dim=300, vocab_size=dist_mat.shape[1],is_train = False)
    
with tf.compat.v1.variable_scope('imdb', reuse=True):
    neighbour_model = models.SentimentModel(batch_size=n1,
                           lstm_size = lstm_size,
                           max_len = max_len,
                           embeddings_dim=300, vocab_size=dist_mat.shape[1],is_train = False)
ga_atttack = GeneticAtack(sess, model, batch_model, neighbour_model, dataset, dist_mat, 
                                  skip_list,
                                  goog_lm, max_iters=30, 
                                   pop_size=pop_size,
                                  n1 = n1,
                                  n2 = 4,
                                 use_lm = False, use_suffix=False)
# Out:
# /Users/tracyzhao/Desktop/nlp_adversarial_examples/models.py:29: UserWarning: `tf.nn.rnn_cell.BasicLSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   lstm = tf.compat.v1.nn.rnn_cell.BasicLSTMCell(self.lstm_size)

# %%
# SAMPLE_SIZE = 5000
SAMPLE_SIZE = 1000
TEST_SIZE = 100
# TEST_SIZE = 100
test_idx = np.random.choice(len(dataset.test_y), SAMPLE_SIZE, replace=False)
test_len = []

for i in range(SAMPLE_SIZE):
    test_len.append(len(dataset.test_seqs2[test_idx[i]]))
print('Shortest sentence in our test set is %d words' %np.min(test_len))

test_list = []
orig_list = []
orig_label_list = []
adv_list = []
dist_list = []

for i in range(SAMPLE_SIZE):
    x_orig = test_x[test_idx[i]]
    orig_label = test_y[test_idx[i]]
    orig_preds=  model.predict(sess, x_orig[np.newaxis, :])[0]
    # print(orig_label, orig_preds, np.argmax(orig_preds))

    # only look at correctly classified examples
    if np.argmax(orig_preds) != orig_label:
        #print('skipping wrong classifed ..')
        #print('--------------------------')
        continue

    x_len = np.sum(np.sign(x_orig))
    if x_len >= 100:
        #print('skipping too long input..')
        #print('--------------------------')
        continue

    # if np.max(orig_preds) < 0.90:
    #    print('skipping low confidence .. \n-----\n')
    #    continue

    print('****** ', len(test_list) + 1, ' ********')
    test_list.append(test_idx[i])
    orig_list.append(x_orig)

    # taret label for the experiment is the opposite of the true label
    target_label = 1 if orig_label == 0 else 0
    orig_label_list.append(orig_label)
    x_adv = ga_atttack.attack(x_orig, target_label)
    adv_list.append(x_adv)

    if x_adv is None:
        print('%d failed' %(i+1))
        dist_list.append(100000)
    else:
        num_changes = np.sum(x_orig != x_adv)
        print('%d - %d changed.' %(i+1, num_changes))
        dist_list.append(num_changes)
        # display_utils.visualize_attack(sess, model, dataset, x_orig, x_adv)
    print('--------------------------')
    
    if (len(test_list)>= TEST_SIZE):
        break
# Out:
# Shortest sentence in our test set is 24 words
# ******  1  ********
# 		 0  --  0.06835136
# 		 1  --  0.16784218
# 		 2  --  0.2430517
# 		 3  --  0.3143901
# 		 4  --  0.3143901
# 		 5  --  0.520079
# 3 - 8 changed.
# --------------------------
# ******  2  ********
# 		 0  --  0.21738793
# 		 1  --  0.3042279
# 		 2  --  0.35626635
# 		 3  --  0.45069996
# 		 4  --  0.6246954
# 12 - 5 changed.
# --------------------------
# ******  3  ********
# 		 0  --  0.041856453
# 		 1  --  0.073732644
# 		 2  --  0.41440216
# 		 3  --  0.6447451
# 18 - 6 changed.
# --------------------------
# ******  4  ********
# 		 0  --  0.08372314
# 		 1  --  0.6673553
# 23 - 3 changed.
# --------------------------
# ******  5  ********
# 		 0  --  0.0027997177
# 		 1  --  0.0067229536
# 		 2  --  0.008506338
# 		 3  --  0.08344418
# 		 4  --  0.19753586
# 		 5  --  0.19753586
# 		 6  --  0.39272025
# 		 7  --  0.46779954
# 		 8  --  0.6312595
# 37 - 11 changed.
# --------------------------
# ******  6  ********
# 		 0  --  0.4059825
# 		 1  --  0.54877144
# 39 - 2 changed.
# --------------------------
# ******  7  ********
# 		 0  --  0.0015202429
# 		 1  --  0.0049918154
# 		 2  --  0.008656821
# 		 3  --  0.01707776
# 		 4  --  0.019747844
# 		 5  --  0.23832525
# 		 6  --  0.31571835
# 		 7  --  0.5477991
# 42 - 16 changed.
# --------------------------
# ******  8  ********
# 		 0  --  0.67587173
# 48 - 1 changed.
# --------------------------
# ******  9  ********
# 		 0  --  0.17008731
# 		 1  --  0.3255105
# 		 2  --  0.6120109
# 65 - 6 changed.
# --------------------------
# ******  10  ********
# 		 0  --  0.14154105
# 		 1  --  0.61288565
# 71 - 3 changed.
# --------------------------
# ******  11  ********
# 		 0  --  0.5449596
# 84 - 1 changed.
# --------------------------
# ******  12  ********
# 		 0  --  0.1448393
# 		 1  --  0.73404235
# 89 - 3 changed.
# --------------------------
# ******  13  ********
# 		 0  --  0.022564646
# 		 1  --  0.48872542
# 		 2  --  0.7060191
# 90 - 4 changed.
# --------------------------
# ******  14  ********
# 		 0  --  0.37304193
# 		 1  --  0.4586508
# 		 2  --  0.4901016
# 		 3  --  0.54590124
# 94 - 4 changed.
# --------------------------
# ******  15  ********
# 		 0  --  0.0016069263
# 		 1  --  0.002022215
# 		 2  --  0.0047842227
# 		 3  --  0.014633296
# 		 4  --  0.032070406
# 		 5  --  0.07608001
# 		 6  --  0.07608001
# 		 7  --  0.07608001
# 		 8  --  0.11736514
# 		 9  --  0.13852969
# 		 10  --  0.276205
# 		 11  --  0.80144745
# 99 - 15 changed.
# --------------------------
# ******  16  ********
# 		 0  --  0.6083906
# 131 - 1 changed.
# --------------------------
# ******  17  ********
# 		 0  --  0.018486287
# 		 1  --  0.045067344
# 		 2  --  0.054253485
# 		 3  --  0.1723814
# 		 4  --  0.19750404
# 		 5  --  0.44407693
# 		 6  --  0.7453514
# 154 - 10 changed.
# --------------------------
# ******  18  ********
# 		 0  --  0.13505252
# 		 1  --  0.20923819
# 		 2  --  0.32276624
# 		 3  --  0.38157347
# 		 4  --  0.43879056
# 		 5  --  0.47403952
# 		 6  --  0.5053691
# 155 - 11 changed.
# --------------------------
# ******  19  ********
# 		 0  --  0.47382638
# 		 1  --  0.5934003
# 174 - 2 changed.
# --------------------------
# ******  20  ********
# 		 0  --  0.0024526955
# 		 1  --  0.0059955395
# 		 2  --  0.0059955395
# 		 3  --  0.010846151
# 		 4  --  0.014754482
# 		 5  --  0.03808995
# 		 6  --  0.09110336
# 		 7  --  0.09110336
# 		 8  --  0.10994241
# 		 9  --  0.10994241
# 		 10  --  0.17105903
# 		 11  --  0.17105903
# 		 12  --  0.18587592
# 		 13  --  0.19194323
# 		 14  --  0.30553564
# 		 15  --  0.42774096
# 		 16  --  0.43999937
# 		 17  --  0.531486
# 204 - 22 changed.
# --------------------------
# ******  21  ********
# 		 0  --  0.2331003
# 		 1  --  0.3802181
# 		 2  --  0.42345953
# 		 3  --  0.5320568
# 205 - 6 changed.
# --------------------------
# ******  22  ********
# 		 0  --  0.6686304
# 216 - 1 changed.
# --------------------------
# ******  23  ********
# 		 0  --  0.10508643
# 		 1  --  0.3419802
# 		 2  --  0.58937883
# 247 - 5 changed.
# --------------------------
# ******  24  ********
# 		 0  --  0.11887455
# 		 1  --  0.25714144
# 		 2  --  0.35714233
# 		 3  --  0.7681054
# 257 - 6 changed.
# --------------------------
# ******  25  ********
# 		 0  --  0.3558113
# 		 1  --  0.42907223
# 		 2  --  0.54288363
# 262 - 5 changed.
# --------------------------
# ******  26  ********
# 		 0  --  0.44145566
# 		 1  --  0.66035163
# 272 - 1 changed.
# --------------------------
# ******  27  ********
# 		 0  --  0.18607956
# 		 1  --  0.35151935
# 		 2  --  0.42590442
# 		 3  --  0.5609684
# 296 - 6 changed.
# --------------------------
# ******  28  ********
# 		 0  --  0.760942
# 297 - 1 changed.
# --------------------------
# ******  29  ********
# 		 0  --  0.033158865
# 		 1  --  0.17043681
# 		 2  --  0.28763884
# 		 3  --  0.81655043
# 298 - 5 changed.
# --------------------------
# ******  30  ********
# 		 0  --  0.05451993
# 		 1  --  0.07553724
# 		 2  --  0.08685248
# 		 3  --  0.35646915
# 		 4  --  0.45538646
# 		 5  --  0.6117661
# 303 - 8 changed.
# --------------------------
# ******  31  ********
# 		 0  --  0.3095108
# 		 1  --  0.41487747
# 		 2  --  0.55345094
# 310 - 6 changed.
# --------------------------
# ******  32  ********
# 		 0  --  0.16793524
# 		 1  --  0.29871997
# 		 2  --  0.74589854
# 311 - 5 changed.
# --------------------------
# ******  33  ********
# 		 0  --  0.0047536246
# 		 1  --  0.0065530925
# 		 2  --  0.0163416
# 		 3  --  0.10450298
# 		 4  --  0.5342081
# 327 - 8 changed.
# --------------------------
# ******  34  ********
# 		 0  --  0.61274296
# 333 - 1 changed.
# --------------------------
# ******  35  ********
# 		 0  --  0.4370263
# 		 1  --  0.6144782
# 351 - 3 changed.
# --------------------------
# ******  36  ********
# 		 0  --  0.61048526
# 353 - 1 changed.
# --------------------------
# ******  37  ********
# 		 0  --  0.044139635
# 		 1  --  0.044139635
# 		 2  --  0.08595613
# 		 3  --  0.35301542
# 		 4  --  0.35301542
# 		 5  --  0.69544387
# 357 - 10 changed.
# --------------------------
# ******  38  ********
# 		 0  --  0.46333364
# 		 1  --  0.5063505
# 363 - 2 changed.
# --------------------------
# ******  39  ********
# 		 0  --  0.3285325
# 		 1  --  0.5393927
# 373 - 2 changed.
# --------------------------
# ******  40  ********
# 		 0  --  0.16602202
# 		 1  --  0.20194936
# 		 2  --  0.3556657
# 		 3  --  0.38880536
# 		 4  --  0.59248894
# 383 - 7 changed.
# --------------------------
# ******  41  ********
# 		 0  --  0.42463684
# 		 1  --  0.68430734
# 397 - 3 changed.
# --------------------------
# ******  42  ********
# 		 0  --  0.08477486
# 		 1  --  0.20386137
# 		 2  --  0.26066858
# 		 3  --  0.377503
# 		 4  --  0.48273322
# 		 5  --  0.5667823
# 399 - 9 changed.
# --------------------------
# ******  43  ********
# 		 0  --  0.12294285
# 		 1  --  0.2554357
# 		 2  --  0.3828848
# 		 3  --  0.6304255
# 404 - 7 changed.
# --------------------------
# ******  44  ********
# 		 0  --  0.6605749
# 423 - 1 changed.
# --------------------------
# ******  45  ********
# 		 0  --  0.14640085
# 		 1  --  0.23869133
# 		 2  --  0.48519495
# 		 3  --  0.65905803
# 424 - 4 changed.
# --------------------------
# ******  46  ********
# 		 0  --  0.4985963
# 		 1  --  0.65381604
# 432 - 3 changed.
# --------------------------
# ******  47  ********
# 		 0  --  0.054595143
# 		 1  --  0.06892667
# 		 2  --  0.09080276
# 		 3  --  0.26091745
# 		 4  --  0.62011236
# 442 - 9 changed.
# --------------------------
# ******  48  ********
# 		 0  --  0.5759728
# 448 - 1 changed.
# --------------------------
# ******  49  ********
# 		 0  --  0.27219552
# 		 1  --  0.46416909
# 		 2  --  0.618691
# 454 - 5 changed.
# --------------------------
# ******  50  ********
# 		 0  --  0.7035592
# 460 - 1 changed.
# --------------------------
# ******  51  ********
# 		 0  --  0.4073538
# 		 1  --  0.6738581
# 462 - 3 changed.
# --------------------------
# ******  52  ********
# 		 0  --  0.3226698
# 		 1  --  0.4113315
# 		 2  --  0.570715
# 466 - 5 changed.
# --------------------------
# ******  53  ********
# 		 0  --  0.002848857
# 		 1  --  0.010274501
# 		 2  --  0.01926174
# 		 3  --  0.05869454
# 		 4  --  0.17148551
# 		 5  --  0.25749788
# 		 6  --  0.38398802
# 		 7  --  0.6330855
# 470 - 10 changed.
# --------------------------
# ******  54  ********
# 		 0  --  0.031941574
# 		 1  --  0.07192848
# 		 2  --  0.07192848
# 		 3  --  0.15191759
# 		 4  --  0.16474305
# 		 5  --  0.18394957
# 		 6  --  0.2786371
# 		 7  --  0.29166272
# 		 8  --  0.29460534
# 		 9  --  0.41222295
# 		 10  --  0.4489745
# 		 11  --  0.59412104
# 473 - 13 changed.
# --------------------------
# ******  55  ********
# 		 0  --  0.038546592
# 		 1  --  0.0777315
# 		 2  --  0.12621246
# 		 3  --  0.1869509
# 		 4  --  0.3789747
# 		 5  --  0.5567152
# 476 - 8 changed.
# --------------------------
# ******  56  ********
# 		 0  --  0.025420345
# 		 1  --  0.07787779
# 		 2  --  0.19125949
# 		 3  --  0.4893276
# 		 4  --  0.61518055
# 479 - 7 changed.
# --------------------------
# ******  57  ********
# 		 0  --  0.72932065
# 481 - 1 changed.
# --------------------------
# ******  58  ********
# 		 0  --  0.15196398
# 		 1  --  0.62365687
# 496 - 3 changed.
# --------------------------
# ******  59  ********
# 		 0  --  0.8208975
# 506 - 1 changed.
# --------------------------
# ******  60  ********
# 		 0  --  0.12122982
# 		 1  --  0.15193222
# 		 2  --  0.28496495
# 		 3  --  0.33185318
# 		 4  --  0.5619236
# 529 - 5 changed.
# --------------------------
# ******  61  ********
# 		 0  --  0.7768528
# 536 - 1 changed.
# --------------------------
# ******  62  ********
# 		 0  --  0.01207015
# 		 1  --  0.027727306
# 		 2  --  0.027727306
# 		 3  --  0.040060405
# 		 4  --  0.16863436
# 		 5  --  0.16863436
# 		 6  --  0.20441055
# 		 7  --  0.23458263
# 		 8  --  0.54738235
# 540 - 12 changed.
# --------------------------
# ******  63  ********
# 		 0  --  0.5485723
# 570 - 1 changed.
# --------------------------
# ******  64  ********
# 		 0  --  0.35542017
# 		 1  --  0.47549954
# 		 2  --  0.5842978
# 588 - 4 changed.
# --------------------------
# ******  65  ********
# 		 0  --  0.13499735
# 		 1  --  0.21695141
# 		 2  --  0.31465137
# 		 3  --  0.43970346
# 		 4  --  0.46835
# 		 5  --  0.5918768
# 591 - 10 changed.
# --------------------------
# ******  66  ********
# 		 0  --  0.1562671
# 		 1  --  0.20498756
# 		 2  --  0.31120026
# 		 3  --  0.34248227
# 		 4  --  0.49478325
# 		 5  --  0.50517
# 594 - 9 changed.
# --------------------------
# ******  67  ********
# 		 0  --  0.07685913
# 		 1  --  0.16359414
# 		 2  --  0.19438279
# 		 3  --  0.24013165
# 		 4  --  0.3059413
# 		 5  --  0.32396382
# 		 6  --  0.32523587
# 		 7  --  0.36565778
# 		 8  --  0.37773833
# 		 9  --  0.37773833
# 		 10  --  0.39677325
# 		 11  --  0.39866287
# 		 12  --  0.41178384
# 		 13  --  0.41609845
# 		 14  --  0.41616318
# 		 15  --  0.4249924
# 		 16  --  0.4249924
# 		 17  --  0.4249924
# 		 18  --  0.4249924
# 		 19  --  0.4249924
# 		 20  --  0.4249924
# 		 21  --  0.4249924
# 		 22  --  0.4249924
# 		 23  --  0.4249924
# 		 24  --  0.4249924
# 		 25  --  0.4249924
# 		 26  --  0.4249924
# 		 27  --  0.4249924
# 		 28  --  0.4249924
# 		 29  --  0.4249924
# 599 failed
# --------------------------
# ******  68  ********
# 		 0  --  0.09460348
# 		 1  --  0.26633477
# 		 2  --  0.37832558
# 		 3  --  0.7017346
# 608 - 5 changed.
# --------------------------
# ******  69  ********
# 		 0  --  0.08709104
# 		 1  --  0.28981045
# 		 2  --  0.58191365
# 615 - 5 changed.
# --------------------------
# ******  70  ********
# 		 0  --  0.06493873
# 		 1  --  0.1819262
# 		 2  --  0.47251353
# 		 3  --  0.48062047
# 		 4  --  0.6555841
# 632 - 7 changed.
# --------------------------
# ******  71  ********
# 		 0  --  0.31806758
# 		 1  --  0.49289957
# 		 2  --  0.5772342
# 659 - 4 changed.
# --------------------------
# ******  72  ********
# 		 0  --  0.5664376
# 669 - 1 changed.
# --------------------------
# ******  73  ********
# 		 0  --  0.8220665
# 671 - 1 changed.
# --------------------------
# ******  74  ********
# 		 0  --  0.5322904
# 723 - 1 changed.
# --------------------------
# ******  75  ********
# 		 0  --  0.049893204
# 		 1  --  0.06195068
# 		 2  --  0.117335916
# 		 3  --  0.20037615
# 		 4  --  0.36738896
# 		 5  --  0.37719572
# 		 6  --  0.4839192
# 		 7  --  0.73229265
# 731 - 13 changed.
# --------------------------
# ******  76  ********
# 		 0  --  0.11483798
# 		 1  --  0.11724939
# 		 2  --  0.19341338
# 		 3  --  0.22435707
# 		 4  --  0.31441653
# 		 5  --  0.49292365
# 		 6  --  0.7272665
# 738 - 11 changed.
# --------------------------
# ******  77  ********
# 		 0  --  0.008739013
# 		 1  --  0.025447529
# 		 2  --  0.033265807
# 		 3  --  0.130314
# 		 4  --  0.54455143
# 743 - 8 changed.
# --------------------------
# ******  78  ********
# 		 0  --  0.9379048
# 747 - 1 changed.
# --------------------------
# ******  79  ********
# 		 0  --  0.72323275
# 763 - 1 changed.
# --------------------------
# ******  80  ********
# 		 0  --  0.63502496
# 790 - 1 changed.
# --------------------------
# ******  81  ********
# 		 0  --  0.09663126
# 		 1  --  0.3126899
# 		 2  --  0.54864776
# 793 - 4 changed.
# --------------------------
# ******  82  ********
# 		 0  --  0.03841855
# 		 1  --  0.04361297
# 		 2  --  0.08020159
# 		 3  --  0.1789614
# 		 4  --  0.25824824
# 		 5  --  0.5960982
# 802 - 9 changed.
# --------------------------
# ******  83  ********
# 		 0  --  0.23050761
# 		 1  --  0.33663073
# 		 2  --  0.5228795
# 804 - 5 changed.
# --------------------------
# ******  84  ********
# 		 0  --  0.08888248
# 		 1  --  0.13851742
# 		 2  --  0.15662538
# 		 3  --  0.1815207
# 		 4  --  0.21671753
# 		 5  --  0.28483286
# 		 6  --  0.3018816
# 		 7  --  0.41130126
# 		 8  --  0.46842355
# 		 9  --  0.56640667
# 821 - 14 changed.
# --------------------------
# ******  85  ********
# 		 0  --  0.32664615
# 		 1  --  0.4839707
# 		 2  --  0.6187883
# 822 - 3 changed.
# --------------------------
# ******  86  ********
# 		 0  --  0.015708528
# 		 1  --  0.022766119
# 		 2  --  0.034403417
# 		 3  --  0.06444094
# 		 4  --  0.11817217
# 		 5  --  0.17551565
# 		 6  --  0.21010539
# 		 7  --  0.24690524
# 		 8  --  0.24690524
# 		 9  --  0.24690524
# 		 10  --  0.24878585
# 		 11  --  0.2818571
# 		 12  --  0.3319304
# 		 13  --  0.36667806
# 		 14  --  0.41359717
# 		 15  --  0.42562354
# 		 16  --  0.43639064
# 		 17  --  0.44609335
# 		 18  --  0.44934264
# 		 19  --  0.44934264
# 		 20  --  0.44934264
# 		 21  --  0.44934264
# 		 22  --  0.44934264
# 		 23  --  0.44934264
# 		 24  --  0.44934264
# 		 25  --  0.45053333
# 		 26  --  0.45053333
# 		 27  --  0.45053333
# 		 28  --  0.45053333
# 		 29  --  0.45053333
# 824 failed
# --------------------------
# ******  87  ********
# 		 0  --  0.06589511
# 		 1  --  0.25764126
# 		 2  --  0.26970345
# 		 3  --  0.53203577
# 835 - 7 changed.
# --------------------------
# ******  88  ********
# 		 0  --  0.22520971
# 		 1  --  0.29897645
# 		 2  --  0.48769137
# 		 3  --  0.7266598
# 840 - 5 changed.
# --------------------------
# ******  89  ********
# 		 0  --  0.14150785
# 		 1  --  0.16001749
# 		 2  --  0.21890172
# 		 3  --  0.25575206
# 		 4  --  0.32080513
# 		 5  --  0.3212544
# 		 6  --  0.40073043
# 		 7  --  0.44122082
# 		 8  --  0.46685725
# 		 9  --  0.5335232
# 847 - 14 changed.
# --------------------------
# ******  90  ********
# 		 0  --  0.09001051
# 		 1  --  0.1834969
# 		 2  --  0.9101224
# 858 - 3 changed.
# --------------------------
# ******  91  ********
# 		 0  --  0.030663708
# 		 1  --  0.04550937
# 		 2  --  0.12779817
# 		 3  --  0.16386913
# 		 4  --  0.2224761
# 		 5  --  0.3146518
# 		 6  --  0.33747286
# 		 7  --  0.48206326
# 		 8  --  0.567007
# 876 - 16 changed.
# --------------------------
# ******  92  ********
# 		 0  --  0.16844207
# 		 1  --  0.31886178
# 		 2  --  0.43463376
# 		 3  --  0.69027597
# 880 - 7 changed.
# --------------------------
# ******  93  ********
# 		 0  --  0.070310265
# 		 1  --  0.15262128
# 		 2  --  0.6151947
# 895 - 5 changed.
# --------------------------
# ******  94  ********
# 		 0  --  0.2221783
# 		 1  --  0.37473136
# 		 2  --  0.44303206
# 		 3  --  0.5194962
# 896 - 6 changed.
# --------------------------
# ******  95  ********
# 		 0  --  0.25094295
# 		 1  --  0.52116746
# 903 - 3 changed.
# --------------------------
# ******  96  ********
# 		 0  --  0.052000333
# 		 1  --  0.08797177
# 		 2  --  0.38273326
# 		 3  --  0.80062294
# 920 - 5 changed.
# --------------------------
# ******  97  ********
# 		 0  --  0.004670438
# 		 1  --  0.0048423735
# 		 2  --  0.0048423735
# 		 3  --  0.010551869
# 		 4  --  0.010551863
# 		 5  --  0.017422557
# 		 6  --  0.018610936
# 		 7  --  0.1557288
# 		 8  --  0.16509742
# 		 9  --  0.16509742
# 		 10  --  0.16963933
# 		 11  --  0.20802099
# 		 12  --  0.27943555
# 		 13  --  0.38871273
# 		 14  --  0.4152565
# 		 15  --  0.50750613
# 922 - 18 changed.
# --------------------------
# ******  98  ********
# 		 0  --  0.13313213
# 		 1  --  0.56990093
# 924 - 2 changed.
# --------------------------
# ******  99  ********
# 		 0  --  0.5076935
# 948 - 1 changed.
# --------------------------
# ******  100  ********
# 		 0  --  0.5783409
# 962 - 1 changed.
# --------------------------

# %% [markdown]
# ## Compute Attack success rate

# %%
orig_len = [np.sum(np.sign(x)) for x in orig_list]
normalized_dist_list = [dist_list[i]/orig_len[i] for i in range(len(orig_list)) ]

# %%
SUCCESS_THRESHOLD  = 0.25
successful_attacks = [x < SUCCESS_THRESHOLD for x in normalized_dist_list]
print('Attack success rate : {:.2f}%'.format(np.mean(successful_attacks)*100))
print('Median percentange of modifications: {:.02f}% '.format(
    np.median([x for x in normalized_dist_list if x < 1])*100))
print('Mean percentange of modifications: {:.02f}% '.format(
    np.mean([x for x in normalized_dist_list if x < 1])*100))
# Out:
# Attack success rate : 96.00%
# Median percentange of modifications: 7.35%
# Mean percentange of modifications: 8.44%

# %% [markdown]
# ## Adversarial Examples Generated

# %%
visual_idx = np.random.choice(len(orig_list))
display_utils.visualize_attack(sess, model, dataset, orig_list[visual_idx], adv_list[visual_idx])
# Out:
# Original Prediction = Negative. (Confidence = 74.04)
# <b style='color:green'>camp</b> blood looked <b style='color:green'>great</b> when i was buying it but when i watched it boy was i wrong its <b style='color:green'>tacky</b> the acting is outrageous and the quality of the film is shocking being a movie fan i usually find humour from tragic horror but at times i couldn't even laugh maybe camp blood 2 will be an improvement
# ---------  After attack -------------
# New Prediction = Positive. (Confidence = 67.39)
# <b style='color:red'>camping</b> blood looked <b style='color:red'>wonderful</b> when i was buying it but when i watched it boy was i wrong its <b style='color:red'>dorky</b> the acting is outrageous and the quality of the film is shocking being a movie fan i usually find humour from tragic horror but at times i couldn't even laugh maybe camp blood 2 will be an improvement

# %%
visual_idx = np.random.choice(len(orig_list))
display_utils.visualize_attack(sess, model, dataset, orig_list[visual_idx], adv_list[visual_idx])
# Out:
# Original Prediction = Positive. (Confidence = 98.72)
# this <b style='color:green'>short</b> was nominated for an academy award losing to anna and bella not since doctor strangelove has nuclear war been so <b style='color:green'>hilarious</b> takes a situation and turns it on its ear and then gives it a spin for <b style='color:green'>good</b> measure visual gags abound in work and i always see <b style='color:green'>something</b> i missed before every time i watch this on the world's greatest animation well worth seeing for many <b style='color:green'>other</b> shorts recommended
# ---------  After attack -------------
# New Prediction = Negative. (Confidence = 58.94)
# this <b style='color:red'>shorted</b> was nominated for an academy award losing to anna and bella not since doctor strangelove has nuclear war been so <b style='color:red'>comic</b> takes a situation and turns it on its ear and then gives it a spin for <b style='color:red'>alright</b> measure visual gags abound in work and i always see <b style='color:red'>nothing</b> i missed before every time i watch this on the world's greatest animation well worth seeing for many <b style='color:red'>else</b> shorts recommended

# %%
## Save success
with open('attack_results_final.pkl', 'wb') as f:
    pickle.dump((test_list, orig_list, orig_label_list, adv_list, normalized_dist_list), f)
